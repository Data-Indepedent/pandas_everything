# %% [markdown]
# ### Mulitplying columns together to make a 3rd column
#
# Goal: Multiply columns

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Street_Tree_List.csv')

# %%
df.head(2)
# Out:
#    TreeID    qLegalStatus                                 qSpecies  \
# 0   46534  Permitted Site                               Tree(s) ::
# 1  121399  DPW Maintained  Corymbia ficifolia :: Red Flowering Gum
#
#          qAddress  SiteOrder                     qSiteInfo PlantType  \
# 0    73 Summer St        7.0  Sidewalk: Curb side : Cutout      Tree
# 1  349X Cargo Way        1.0  Sidewalk: Curb side : Cutout      Tree
#
#   qCaretaker qCareAssistant               PlantDate  ...  XCoord YCoord  \
# 0    Private            NaN  04/01/2002 12:00:00 AM  ...     NaN    NaN
# 1        DPW            NaN                     NaN  ...     NaN    NaN
#
#   Latitude  Longitude  Location  Fire Prevention Districts  Police Districts  \
# 0      NaN        NaN       NaN                        NaN               NaN
# 1      NaN        NaN       NaN                        NaN               NaN
#
#   Supervisor Districts  Zip Codes  Neighborhoods (old)
# 0                  NaN        NaN                  NaN
# 1                  NaN        NaN                  NaN
#
# [2 rows x 23 columns]

# %% [markdown]
# #### Method 1: Multiply Series together

# %%
df['multiplied_column'] = df['TreeID'] * df['SiteOrder']

# %% [markdown]
# #### Method 2: Iterate through column and multiply

# %%
results_list = []

for i, row in df.iterrows():
    result = (row['TreeID']/2) * row['SiteOrder']
    results_list.append(result)

# %%
df['multiplied_column2'] = results_list

# %%
df.head(3)
# Out:
#    TreeID    qLegalStatus                                    qSpecies  \
# 0   46534  Permitted Site                                  Tree(s) ::
# 1  121399  DPW Maintained     Corymbia ficifolia :: Red Flowering Gum
# 2   85269  Permitted Site  Arbutus 'Marina' :: Hybrid Strawberry Tree
#
#             qAddress  SiteOrder                     qSiteInfo PlantType  \
# 0       73 Summer St        7.0  Sidewalk: Curb side : Cutout      Tree
# 1     349X Cargo Way        1.0  Sidewalk: Curb side : Cutout      Tree
# 2  1000 Edinburgh St        3.0  Sidewalk: Curb side : Cutout      Tree
#
#   qCaretaker qCareAssistant               PlantDate  ...  Latitude Longitude  \
# 0    Private            NaN  04/01/2002 12:00:00 AM  ...       NaN       NaN
# 1        DPW            NaN                     NaN  ...       NaN       NaN
# 2    Private            NaN  07/24/2007 12:00:00 AM  ...       NaN       NaN
#
#   Location  Fire Prevention Districts  Police Districts  Supervisor Districts  \
# 0      NaN                        NaN               NaN                   NaN
# 1      NaN                        NaN               NaN                   NaN
# 2      NaN                        NaN               NaN                   NaN
#
#    Zip Codes Neighborhoods (old)  multiplied_column  multiplied_column2
# 0        NaN                 NaN           325738.0            162869.0
# 1        NaN                 NaN           121399.0             60699.5
# 2        NaN                 NaN           255807.0            127903.5
#
# [3 rows x 25 columns]
